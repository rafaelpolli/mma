# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "Multi-agent Collaboration"

os.environ["MODEL"] = "gpt-4o-mini-2024-07-18"

os.environ["WORKING_DIRECTORY"] = os.getcwd() + '/files'

# %%
from hma.utils import *
import hma.search as search
import hma.writer as writer
import hma.coordinator as coordinator
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
vector_store_init(persist_directory = "data",
                        collection_name = "gdp",
                        doc = "content.txt",
                  append = False)
# Out:
# /home/studio-lab-user/.conda/envs/custom_python/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:151: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /home/studio-lab-user/.conda/envs/custom_python/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:151: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 0.4. An updated version of the class exists in the langchain-chroma package and should be used instead. To use it run `pip install -U langchain-chroma` and import as `from langchain_chroma import Chroma`.
#   warn_deprecated(

# %%
search_team = search.Search()

# %%
from IPython.display import Image, display

display(Image(search_team.chain.get_graph(xray=True).draw_mermaid_png()))

# %%
#for s in research_team.research_chain.stream(
#    "when is Taylor Swift's next tour?", {"recursion_limit": 100}
#):
#    if "__end__" not in s:
#        print(s)
#        print("---")

# %%
writer_team = writer.Writer()

# %%
from IPython.display import Image, display

display(Image(writer_team.chain.get_graph().draw_mermaid_png()))

# %%
#for s in writer_team.authoring_chain.stream(
#    "Write an outline for poem and then write the poem to disk.",
#    {"recursion_limit": 100},
#):
#    if "__end__" not in s:
#        print(s)
#        print("---")

# %%
main_coordinator = coordinator.Coordinator()

# %%
from IPython.display import Image, display

display(Image(main_coordinator.super_graph.get_graph().draw_mermaid_png()))

# %%
for s in main_coordinator.super_graph.stream(
    {
        "messages": [
            HumanMessage(
                content="Search and Write a customer service script file on 'Como transferir um veículo no estado de SP'."
            )
        ],
    },
    {"recursion_limit": 150},
):
    if "__end__" not in s:
        print(s)
        print("---")
# Out:
# Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# {'SearchTeam': {'messages': [HumanMessage(content='Here is a customer service script regarding the transfer of a vehicle in the state of São Paulo:\n\n---\n\n**Customer Service Script: Como Transferir um Veículo no Estado de SP**\n\n**Introdução:**\nAtendente: Olá! Bem-vindo ao nosso atendimento. Como posso ajudá-lo hoje?\n\n**Cliente:**\nEstou interessado em saber como transferir um veículo no estado de São Paulo.\n\n**Atendente:**\nClaro! Posso ajudá-lo com isso. A transferência de um veículo em São Paulo pode ser feita de forma presencial ou digital. Você gostaria de saber sobre o processo digital ou o presencial?\n\n**Se o cliente escolher digital:**\n\n**Atendente:**\nPara realizar a transferência digital, você pode seguir os seguintes passos:\n\n1. Acesse o site do Detran-SP ou utilize o aplicativo Poupatempo.\n2. Faça login com seus dados pessoais.\n3. Preencha o formulário de transferência de propriedade do veículo.\n4. Anexe os documentos necessários, como:\n   - Documento de Identidade (RG)\n   - CPF\n   - Comprovante de endereço\n   - CRV (Certificado de Registro de Veículo) assinado\n5. Pague a taxa de transferência, que pode variar conforme o município.\n6. Após a confirmação do pagamento, a transferência será processada.\n\n**Cliente:**\nE se eu quiser fazer o processo presencialmente?\n\n**Atendente:**\nSe você preferir fazer a transferência presencialmente, siga estes passos:\n\n1. Dirija-se a uma unidade do Detran-SP ou do Poupatempo.\n2. Leve os documentos necessários, que incluem:\n   - Documento de Identidade (RG)\n   - CPF\n   - Comprovante de endereço\n   - CRV (Certificado de Registro de Veículo) assinado\n3. Solicite o serviço de transferência de propriedade.\n4. Pague a taxa de transferência no local.\n5. Aguarde a finalização do processo, que pode levar alguns dias.\n\n**Cliente:**\nQuais são as taxas envolvidas?\n\n**Atendente:**\nAs taxas de transferência podem variar de acordo com a cidade e o tipo de veículo. É recomendável verificar diretamente no site do Detran-SP ou no aplicativo Poupatempo para obter informações atualizadas sobre valores.\n\n**Cliente:**\nE quanto tempo leva para a transferência ser concluída?\n\n**Atendente:**\nSe realizada digitalmente, a transferência é geralmente concluída em poucos dias. Se feita presencialmente, pode levar um pouco mais de tempo, dependendo da demanda no local.\n\n**Cliente:**\nMuito obrigado pela ajuda!\n\n**Atendente:**\nDe nada! Se precisar de mais informações ou ajuda, não hesite em entrar em contato. Tenha um ótimo dia!\n\n---\n\n**Links Úteis:**\n- [Detran-SP - Transferência de Veículo](https://www.detran.sp.gov.br/wps/portal/portaldetran/cidadao/veiculos/fichaservico/TransferenciaVeiculo)\n- [Poupatempo](https://www.poupatempo.sp.gov.br/)\n\n---\n\nEspero que este script atenda às suas necessidades! Se precisar de mais informações ou ajustes, estou à disposição.', name='WebScraper')]}}
# ---
# {'coordinator': {'next': 'WritingTeam'}}
# ---
# {'WritingTeam': {'messages': [HumanMessage(content='The customer service script regarding the transfer of a vehicle in the state of São Paulo has been successfully created and saved. If you need any further information or adjustments, feel free to ask!', name='DocWriter')]}}
# ---
# {'coordinator': {'next': 'FINISH'}}
# ---
# {'WritingTeam': {'messages': [HumanMessage(content='The customer service script regarding the transfer of a vehicle in the state of São Paulo has been successfully created and saved in the file "customer_service_script_transferencia_veiculo_SP.txt". If you need any further modifications or additional information, feel free to ask!', name='DocWriter')]}}
# ---
# {'coordinator': {'next': 'FINISH'}}
# ---
